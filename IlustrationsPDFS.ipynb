# %% [markdown]
# ## History Data

# %%
import os
import sys
import pandas as pd
import fsp as fsp
from scipy.io import loadmat
import numpy as np

# %% [markdown]
# Divergence measure case 0

# %%
data = loadmat('Datasets/mvnrnd01.mat')
opt = {
    'initial_k': 1,
    'p_parameter': 0.05,
    'h_threshold': 0,
    'dm_case': 2,
    'dm_threshold': 0.5,
    'update_dm_threshold': True,
    'return_full_dm': False,
    'return_full_history': True,
    'iteration_threshold': 2e6,
    'rng_default': False,
    'PD_case': 2,
    'NumberOfRuns': 10,
    'KFold': 10,
    'knn_NumNeighbors': int(np.floor(np.sqrt(len(data['y']))))
}
fsp0_rmH, fsp0_H = fsp.Feature_Space_Partition(data['X'], data['y'], opt)

# %%
df_fsp0_H = pd.DataFrame(fsp0_H)
df_fsp0_H['rmXidx'] = df_fsp0_H['rmXidx'].apply(lambda x: f'{x.shape}' if isinstance(x, np.ndarray) else f'[]')

# %%
display(df_fsp0_H)
# Out:
#     i  k                                                  C  dm_threshold  \
# 0   1  1      [[-0.08491699753484326, 0.10262847037486346]]           0.5
# 1   2  2  [[3.270101431055217, 0.23296858048556832], [-2...           0.5
# 2   3  1      [[-2.959375757308288, -0.009042234043591873]]           0.5
# 3   4  2  [[-2.6886436735150623, 1.3656866575218454], [-...           0.5
# 4   5  3  [[-4.17426792628728, -2.084889377083529], [-3....           0.5
# 5   6  1       [[-1.3329591868885595, -0.4355157920645224]]           0.5
# 6   7  2  [[-0.976136784253399, -2.2631141810747155], [-...           0.5
# 7   8  3  [[-0.7516248074354847, 0.5129796411379925], [-...           0.5
# 8   9  4  [[-0.848264848853105, 1.152629125022288], [-0....           0.5
# 9  10  1       [[-0.8392797071304606, -0.5098296582783117]]           0.5
#
#          dm                               ClassLabelProportion  \
# 0  3.802913                                       [[0.5, 0.5]]
# 1        []  [[0.030959752321981424, 0.9690402476780186], [...
# 2  1.641057        [[0.9018567639257294, 0.09814323607427056]]
# 3  1.967748  [[0.8863636363636364, 0.11363636363636363], [0...
# 4        []  [[0.9811320754716981, 0.018867924528301886], [...
# 5   0.88845        [[0.7401574803149606, 0.25984251968503935]]
# 6  1.075986  [[0.7333333333333333, 0.26666666666666666], [0...
# 7  0.869034  [[0.58, 0.42], [0.7037037037037037, 0.29629629...
# 8        []  [[0.5769230769230769, 0.4230769230769231], [0....
# 9  0.381547        [[0.6309523809523809, 0.36904761904761907]]
#
#      DominantClassLabel                      DominantClassLabel_Proportion  \
# 0                 [0.0]                                              [0.5]
# 1            [1.0, 0.0]           [0.9690402476780186, 0.9018567639257294]
# 2                 [0.0]                               [0.9018567639257294]
# 3            [0.0, 0.0]           [0.8863636363636364, 0.9235668789808917]
# 4       [0.0, 0.0, 0.0]  [0.9811320754716981, 0.9861111111111112, 0.740...
# 5                 [0.0]                               [0.7401574803149606]
# 6            [0.0, 0.0]           [0.7333333333333333, 0.7422680412371134]
# 7       [0.0, 0.0, 0.0]                   [0.58, 0.7037037037037037, 0.92]
# 8  [0.0, 0.0, 0.0, 0.0]  [0.5769230769230769, 0.625, 0.6923076923076923...
# 9                 [0.0]                               [0.6309523809523809]
#
#   ClusterClassificationError  ClassificationError      sum1  rmXidx  \
# 0                      [1.0]             1.000000        []    (0,)
# 1  [0.9690402476780186, 1.0]             0.985714  0.447143  (323,)
# 2                      [1.0]             0.985714        []    (0,)
# 3                 [1.0, 1.0]             0.985714        []    (0,)
# 4            [1.0, 1.0, 1.0]             0.985714  0.357143  (250,)
# 5                      [1.0]             0.985714        []    (0,)
# 6                 [1.0, 1.0]             0.985714        []    (0,)
# 7            [1.0, 1.0, 1.0]             0.985714        []    (0,)
# 8       [1.0, 1.0, 1.0, 1.0]             0.985714  0.061429   (43,)
# 9                      [1.0]             0.985714      0.12   (84,)
#
#    ElapsedTime                              ClassLabel_Proportion
# 0     0.004725                                       [[0.5, 0.5]]
# 1     0.003689  [[0.030959752321981424, 0.9690402476780186], [...
# 2     0.030017        [[0.9018567639257294, 0.09814323607427056]]
# 3     0.002693  [[0.8863636363636364, 0.11363636363636363], [0...
# 4     0.002981  [[0.9811320754716981, 0.018867924528301886], [...
# 5     0.000956        [[0.7401574803149606, 0.25984251968503935]]
# 6     0.000863  [[0.7333333333333333, 0.26666666666666666], [0...
# 7     0.001764  [[0.58, 0.42], [0.7037037037037037, 0.29629629...
# 8     0.000865  [[0.5769230769230769, 0.4230769230769231], [0....
# 9     0.000643        [[0.6309523809523809, 0.36904761904761907]]

# %% [markdown]
# Divergence measure case 1

# %%
fsp1_rmH, fsp1_H = fsp.Feature_Space_Partition(data['X'], data['y'], opt)

# %%
df_fsp1_H = pd.DataFrame(fsp1_H)
df_fsp1_H['rmXidx'] = df_fsp1_H['rmXidx'].apply(lambda x: f'{x.shape}' if isinstance(x, np.ndarray) else f'[]')

# %%
display(df_fsp1_H)
# Out:
#    i  k                                                  C  dm_threshold  \
# 0  1  1      [[-0.08491699753484322, 0.10262847037486346]]           0.5
# 1  2  2  [[-2.95937575730829, -0.009042234043591932], [...           0.5
# 2  3  1      [[-2.959375757308288, -0.009042234043591873]]           0.5
# 3  4  2  [[-2.9529315606582522, -1.722497549512147], [-...           0.5
# 4  5  3  [[-2.9549598997993, 2.0920174682512007], [-1.4...           0.5
# 5  6  1       [[-1.4356922967763603, -0.9399845225519329]]           0.5
# 6  7  2  [[-1.3967952070192808, -0.09416133532989568], ...           0.5
# 7  8  3  [[-2.360126964256386, -0.7364509063465573], [-...           0.5
# 8  9  1        [[-0.9404594391977755, -1.049020388376241]]           0.5
#
#          dm                               ClassLabelProportion  \
# 0  3.802913                                       [[0.5, 0.5]]
# 1        []  [[0.9018567639257294, 0.09814323607427056], [0...
# 2  1.641057        [[0.9018567639257294, 0.09814323607427056]]
# 3  1.251612  [[0.8846153846153846, 0.11538461538461539], [0...
# 4        []  [[0.9626865671641791, 0.03731343283582089], [0...
# 5  0.978102        [[0.7674418604651163, 0.23255813953488372]]
# 6  0.832038  [[0.7380952380952381, 0.2619047619047619], [0....
# 7        []  [[0.9555555555555556, 0.044444444444444446], [...
# 8  0.483153         [[0.6666666666666666, 0.3333333333333333]]
#
#   DominantClassLabel                      DominantClassLabel_Proportion  \
# 0              [0.0]                                              [0.5]
# 1         [0.0, 1.0]           [0.9018567639257294, 0.9690402476780186]
# 2              [0.0]                               [0.9018567639257294]
# 3         [0.0, 0.0]           [0.8846153846153846, 0.9179487179487179]
# 4    [0.0, 0.0, 0.0]  [0.9626865671641791, 0.7674418604651163, 0.982...
# 5              [0.0]                               [0.7674418604651163]
# 6         [0.0, 0.0]           [0.7380952380952381, 0.8222222222222222]
# 7    [0.0, 0.0, 0.0]      [0.9555555555555556, 0.7647058823529411, 0.6]
# 8              [0.0]                               [0.6666666666666666]
#
#   ClusterClassificationError  ClassificationError      sum1  rmXidx  \
# 0                      [1.0]             1.000000        []    (0,)
# 1  [1.0, 0.9690402476780186]             0.985714  0.447143  (323,)
# 2                      [1.0]             0.985714        []    (0,)
# 3                 [1.0, 1.0]             0.985714        []    (0,)
# 4            [1.0, 1.0, 1.0]             0.985714  0.354286  (248,)
# 5                      [1.0]             0.985714        []    (0,)
# 6                 [1.0, 1.0]             0.985714        []    (0,)
# 7            [1.0, 1.0, 1.0]             0.985714  0.064286   (45,)
# 8                      [1.0]             0.985714      0.12   (84,)
#
#    ElapsedTime                              ClassLabel_Proportion
# 0     0.004374                                       [[0.5, 0.5]]
# 1     0.002847  [[0.9018567639257294, 0.09814323607427056], [0...
# 2     0.001776        [[0.9018567639257294, 0.09814323607427056]]
# 3     0.001553  [[0.8846153846153846, 0.11538461538461539], [0...
# 4     0.002387  [[0.9626865671641791, 0.03731343283582089], [0...
# 5     0.001081        [[0.7674418604651163, 0.23255813953488372]]
# 6     0.000860  [[0.7380952380952381, 0.2619047619047619], [0....
# 7     0.000800  [[0.9555555555555556, 0.044444444444444446], [...
# 8     0.000616         [[0.6666666666666666, 0.3333333333333333]]

# %% [markdown]
# Divergence measure case 2

# %%
fsp2_rmH, fsp2_H = fsp.Feature_Space_Partition(data['X'], data['y'], opt)

# %%
df_fsp2_H = pd.DataFrame(fsp2_H)
df_fsp2_H['rmXidx'] = df_fsp2_H['rmXidx'].apply(lambda x: f'{x.shape}' if isinstance(x, np.ndarray) else f'[]')

# %%
display(df_fsp2_H)
# Out:
#     i  k                                                  C  dm_threshold  \
# 0   1  1      [[-0.08491699753484322, 0.10262847037486346]]           0.5
# 1   2  2  [[3.270101431055217, 0.23296858048556834], [-2...           0.5
# 2   3  1      [[-2.959375757308288, -0.009042234043591873]]           0.5
# 3   4  2  [[-2.717979585487558, 1.3634377000947513], [-3...           0.5
# 4   5  3  [[-3.7218808175826, 1.8864053068994533], [-1.3...           0.5
# 5   6  1      [[-1.3640482675490464, -0.11442730873284014]]           0.5
# 6   7  2  [[-1.4982097666816792, -0.9078314874829105], [...           0.5
# 7   8  3  [[-2.110936776875371, -0.24677296385422615], [...           0.5
# 8   9  4  [[-2.310973459164145, -0.25498825334610975], [...           0.5
# 9  10  1      [[-0.863986649505118, -0.040198495285383246]]           0.5
#
#          dm                               ClassLabelProportion  \
# 0  3.802913                                       [[0.5, 0.5]]
# 1        []  [[0.030959752321981424, 0.9690402476780186], [...
# 2  1.641057        [[0.9018567639257294, 0.09814323607427056]]
# 3  1.943733  [[0.8914027149321267, 0.1085972850678733], [0....
# 4        []  [[0.9924242424242424, 0.007575757575757576], [...
# 5  0.915331                                     [[0.75, 0.25]]
# 6  0.881252  [[0.7590361445783133, 0.24096385542168675], [0...
# 7  1.237965  [[0.8793103448275862, 0.1206896551724138], [0....
# 8        []  [[0.9574468085106383, 0.0425531914893617], [0....
# 9  0.369756         [[0.6404494382022472, 0.3595505617977528]]
#
#      DominantClassLabel                      DominantClassLabel_Proportion  \
# 0                 [0.0]                                              [0.5]
# 1            [1.0, 0.0]           [0.9690402476780186, 0.9018567639257294]
# 2                 [0.0]                               [0.9018567639257294]
# 3            [0.0, 0.0]           [0.8914027149321267, 0.9166666666666666]
# 4       [0.0, 0.0, 0.0]      [0.9924242424242424, 0.75, 0.981651376146789]
# 5                 [0.0]                                             [0.75]
# 6            [0.0, 0.0]           [0.7590361445783133, 0.7358490566037735]
# 7       [0.0, 0.0, 0.0]  [0.8793103448275862, 0.6129032258064516, 0.680...
# 8  [0.0, 0.0, 0.0, 0.0]  [0.9574468085106383, 0.5714285714285714, 0.718...
# 9                 [0.0]                               [0.6404494382022472]
#
#   ClusterClassificationError  ClassificationError      sum1  rmXidx  \
# 0                      [1.0]             1.000000        []    (0,)
# 1  [0.9690402476780186, 1.0]             0.985714  0.447143  (323,)
# 2                      [1.0]             0.985714        []    (0,)
# 3                 [1.0, 1.0]             0.985714        []    (0,)
# 4            [1.0, 1.0, 1.0]             0.985714  0.344286  (241,)
# 5                      [1.0]             0.985714        []    (0,)
# 6                 [1.0, 1.0]             0.985714        []    (0,)
# 7            [1.0, 1.0, 1.0]             0.985714        []    (0,)
# 8       [1.0, 1.0, 1.0, 1.0]             0.985714  0.067143   (47,)
# 9                      [1.0]             0.985714  0.127143   (89,)
#
#    ElapsedTime                              ClassLabel_Proportion
# 0     0.003979                                       [[0.5, 0.5]]
# 1     0.003082  [[0.030959752321981424, 0.9690402476780186], [...
# 2     0.001645        [[0.9018567639257294, 0.09814323607427056]]
# 3     0.001676  [[0.8914027149321267, 0.1085972850678733], [0....
# 4     0.001496  [[0.9924242424242424, 0.007575757575757576], [...
# 5     0.000759                                     [[0.75, 0.25]]
# 6     0.000872  [[0.7590361445783133, 0.24096385542168675], [0...
# 7     0.000847  [[0.8793103448275862, 0.1206896551724138], [0....
# 8     0.001009  [[0.9574468085106383, 0.0425531914893617], [0....
# 9     0.000602         [[0.6404494382022472, 0.3595505617977528]]

# %% [markdown]
# Divergence measure case 3

# %%
fsp3_rmH, fsp3_H = fsp.Feature_Space_Partition(data['X'], data['y'], opt)

# %%
df_fsp3_H = pd.DataFrame(fsp3_H)
df_fsp3_H['rmXidx'] = df_fsp3_H['rmXidx'].apply(lambda x: f'{x.shape}' if isinstance(x, np.ndarray) else f'[]')

# %%
display(df_fsp3_H)
# Out:
#      i  k                                                  C  dm_threshold  \
# 0    1  1      [[-0.08491699753484326, 0.10262847037486346]]           0.5
# 1    2  2  [[-2.9593757573082904, -0.009042234043591932],...           0.5
# 2    3  1      [[-2.959375757308288, -0.009042234043591873]]           0.5
# 3    4  2  [[-2.6886436735150623, 1.3656866575218454], [-...           0.5
# 4    5  3  [[-1.9578953793372336, 1.4409988006041294], [-...           0.5
# 5    6  1       [[-2.179347310210369, -0.05528175742584159]]           0.5
# 6    7  2  [[-2.5105093719747815, -2.2928389221862573], [...           0.5
# 7    8  3  [[-3.084376376059555, -2.904179094529037], [-2...           0.5
# 8    9  1      [[-1.4461333378469394, -0.33186006464343415]]           0.5
# 9   10  2  [[-0.5910573821004694, -1.436864240840562], [-...           0.5
# 10  11  3  [[-0.7914568228798582, 0.28156597018974905], [...           0.5
# 11  12  1       [[-0.7429585228786952, -0.3747533645483256]]           0.5
#
#           dm                               ClassLabelProportion  \
# 0   3.802913                                       [[0.5, 0.5]]
# 1         []  [[0.9018567639257294, 0.09814323607427056], [0...
# 2   1.641057        [[0.9018567639257294, 0.09814323607427056]]
# 3   1.967748  [[0.8863636363636364, 0.11363636363636363], [0...
# 4         []  [[0.852760736196319, 0.147239263803681], [0.99...
# 5   1.452932         [[0.8676470588235294, 0.1323529411764706]]
# 6   1.284294  [[0.8899082568807339, 0.11009174311926606], [0...
# 7         []  [[0.9701492537313433, 0.029850746268656716], [...
# 8   0.992907         [[0.7391304347826086, 0.2608695652173913]]
# 9   0.561471  [[0.5862068965517241, 0.41379310344827586], [0...
# 10        []  [[0.5777777777777777, 0.4222222222222222], [0....
# 11  0.243651        [[0.5757575757575758, 0.42424242424242425]]
#
#    DominantClassLabel                      DominantClassLabel_Proportion  \
# 0               [0.0]                                              [0.5]
# 1          [0.0, 1.0]           [0.9018567639257294, 0.9690402476780186]
# 2               [0.0]                               [0.9018567639257294]
# 3          [0.0, 0.0]           [0.8863636363636364, 0.9235668789808917]
# 4     [0.0, 0.0, 0.0]  [0.852760736196319, 0.9904761904761905, 0.8899...
# 5               [0.0]                               [0.8676470588235294]
# 6          [0.0, 0.0]            [0.8899082568807339, 0.852760736196319]
# 7     [0.0, 0.0, 0.0]  [0.9701492537313433, 0.9555555555555556, 0.739...
# 8               [0.0]                               [0.7391304347826086]
# 9          [0.0, 0.0]           [0.5862068965517241, 0.7906976744186046]
# 10    [0.0, 0.0, 0.0]  [0.5777777777777777, 0.9591836734693877, 0.571...
# 11              [0.0]                               [0.5757575757575758]
#
#    ClusterClassificationError  ClassificationError      sum1  rmXidx  \
# 0                       [1.0]             1.000000        []    (0,)
# 1   [1.0, 0.9690402476780186]             0.985714  0.447143  (323,)
# 2                       [1.0]             0.985714        []    (0,)
# 3                  [1.0, 1.0]             0.985714        []    (0,)
# 4             [1.0, 1.0, 1.0]             0.985714      0.15  (105,)
# 5                       [1.0]             0.985714        []    (0,)
# 6                  [1.0, 1.0]             0.985714        []    (0,)
# 7             [1.0, 1.0, 1.0]             0.985714  0.224286  (157,)
# 8                       [1.0]             0.985714        []    (0,)
# 9                  [1.0, 1.0]             0.985714        []    (0,)
# 10            [1.0, 1.0, 1.0]             0.985714      0.07   (49,)
# 11                      [1.0]             0.985714  0.094286   (66,)
#
#     ElapsedTime                              ClassLabel_Proportion
# 0      0.005044                                       [[0.5, 0.5]]
# 1      0.003231  [[0.9018567639257294, 0.09814323607427056], [0...
# 2      0.001683        [[0.9018567639257294, 0.09814323607427056]]
# 3      0.001845  [[0.8863636363636364, 0.11363636363636363], [0...
# 4      0.001358  [[0.852760736196319, 0.147239263803681], [0.99...
# 5      0.001149         [[0.8676470588235294, 0.1323529411764706]]
# 6      0.001662  [[0.8899082568807339, 0.11009174311926606], [0...
# 7      0.001109  [[0.9701492537313433, 0.029850746268656716], [...
# 8      0.000672         [[0.7391304347826086, 0.2608695652173913]]
# 9      0.000699  [[0.5862068965517241, 0.41379310344827586], [0...
# 10     0.000736  [[0.5777777777777777, 0.4222222222222222], [0....
# 11     0.000571        [[0.5757575757575758, 0.42424242424242425]]

# %% [markdown]
# Divergence measure case 4

# %%
opt = {
    'dm_case': 4,
    'return_full_history': True,
    'return_full_dm': True,
    'rng_default': True,
}
fsp4_rmH, fsp4_H = fsp.Feature_Space_Partition(data['X'], data['y'], opt)

# %%
df_fsp4_H = pd.DataFrame(fsp4_H)
df_fsp4_H['rmXidx'] = df_fsp4_H['rmXidx'].apply(lambda x: f'{x.shape}' if isinstance(x, np.ndarray) else f'[]')

# %%
display(df_fsp4_H)
# Out:
#     i  k                                                  C  dm_threshold  \
# 0   1  1      [[-0.08491699753484322, 0.10262847037486346]]           0.5
# 1   2  2  [[-2.95937575730829, -0.009042234043591932], [...           0.5
# 2   3  1      [[-2.959375757308288, -0.009042234043591873]]           0.5
# 3   4  2  [[-2.9809725189960683, 1.5648025391478626], [-...           0.5
# 4   5  3  [[-1.331998290204861, -0.38584101922975084], [...           0.5
# 5   6  1       [[-1.3319982902048606, -0.3858410192297508]]           0.5
# 6   7  2  [[-1.022663313090927, -1.93302176931486], [-1....           0.5
# 7   8  3  [[-2.1619012014246266, -0.2823538250845473], [...           0.5
# 8   9  4  [[-1.175138633751376, 1.1084292359233339], [-0...           0.5
# 9  10  1      [[-0.8795302055228421, -0.32051284542959085]]           0.5
#
#                                                   dm  \
# 0                               [2.7274125357426264]
# 1                                                 []
# 2                               [1.2900378279871374]
# 3            [2.294364065730231, 1.0592322878757585]
# 4                                                 []
# 5                               [0.8692024724157754]
# 6           [1.0056804734961236, 1.0857968284238932]
# 7  [0.9706535418701536, 1.7275347213141012, 0.695...
# 8                                                 []
# 9                              [0.37136593946156804]
#
#                                 ClassLabelProportion    DominantClassLabel  \
# 0                                       [[0.5, 0.5]]                 [0.0]
# 1  [[0.9018567639257294, 0.09814323607427056], [0...            [0.0, 1.0]
# 2        [[0.9018567639257294, 0.09814323607427056]]                 [0.0]
# 3  [[0.9191919191919192, 0.08080808080808081], [0...            [0.0, 0.0]
# 4  [[0.736, 0.264], [0.9814814814814815, 0.018518...       [0.0, 0.0, 0.0]
# 5                                   [[0.736, 0.264]]                 [0.0]
# 6  [[0.6857142857142857, 0.3142857142857143], [0....            [0.0, 0.0]
# 7  [[0.9019607843137255, 0.09803921568627451], [0...       [0.0, 0.0, 0.0]
# 8  [[0.7241379310344828, 0.27586206896551724], [0...  [0.0, 0.0, 0.0, 0.0]
# 9        [[0.6352941176470588, 0.36470588235294116]]                 [0.0]
#
#                        DominantClassLabel_Proportion  \
# 0                                              [0.5]
# 1           [0.9018567639257294, 0.9690402476780186]
# 2                               [0.9018567639257294]
# 3             [0.9191919191919192, 0.88268156424581]
# 4    [0.736, 0.9814814814814815, 0.9861111111111112]
# 5                                            [0.736]
# 6           [0.6857142857142857, 0.7555555555555555]
# 7  [0.9019607843137255, 0.6923076923076923, 0.583...
# 8  [0.7241379310344828, 0.6521739130434783, 0.545...
# 9                               [0.6352941176470588]
#
#   ClusterClassificationError  ClassificationError      sum1  rmXidx  \
# 0                      [1.0]             1.000000        []    (0,)
# 1  [1.0, 0.9690402476780186]             0.985714  0.447143  (323,)
# 2                      [1.0]             0.985714        []    (0,)
# 3                 [1.0, 1.0]             0.985714        []    (0,)
# 4            [1.0, 1.0, 1.0]             0.985714      0.36  (252,)
# 5                      [1.0]             0.985714        []    (0,)
# 6                 [1.0, 1.0]             0.985714        []    (0,)
# 7            [1.0, 1.0, 1.0]             0.985714        []    (0,)
# 8       [1.0, 1.0, 1.0, 1.0]             0.985714  0.057143   (40,)
# 9                      [1.0]             0.985714  0.121429   (85,)
#
#    ElapsedTime                              ClassLabel_Proportion
# 0     0.004106                                       [[0.5, 0.5]]
# 1     0.001627  [[0.9018567639257294, 0.09814323607427056], [0...
# 2     0.001895        [[0.9018567639257294, 0.09814323607427056]]
# 3     0.002761  [[0.9191919191919192, 0.08080808080808081], [0...
# 4     0.003079  [[0.736, 0.264], [0.9814814814814815, 0.018518...
# 5     0.001283                                   [[0.736, 0.264]]
# 6     0.001172  [[0.6857142857142857, 0.3142857142857143], [0....
# 7     0.001095  [[0.9019607843137255, 0.09803921568627451], [0...
# 8     0.000845  [[0.7241379310344828, 0.27586206896551724], [0...
# 9     0.000703        [[0.6352941176470588, 0.36470588235294116]]

# %% [markdown]
# ## Plots

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.animation import FuncAnimation

def plot_space_segmentation_process(X, y, H, dm_case, datasetfilename):
    # Compute axis limits
    axis_limits = [np.min(X[:, 0]), np.max(X[:, 0]), np.min(X[:, 1]), np.max(X[:, 1])]
    # Create a tiled chart layout
    fig = plt.figure()
    fig.tight_layout()
    fig.subplots_adjust(wspace=0.1, hspace=0.1)
    pp = PdfPages('multipage.pdf')

    # Loop through the segmentation process
    for i in range(len(H)):
        ax = fig.add_subplot(1, len(H), i+1)
        print("Printando o H[i][C] atual", H[i]['C'])
        _,pp = plot_segmentation(X, y, H[i]['C'], axis_limits,2,pp)
        ax.grid(False)
        ax.set_axis_off()

        # Remove data points of the i-th iteration
        rmidx = H[i]['rmXidx']
        if rmidx.size > 0:
            X = np.delete(X, rmidx, axis=0)
            y = np.delete(y, rmidx)

    # Save the figure with a transparent background
    pp.close()

# %%
def plot_segmentation(X, y, centroids=None, axis_limits=None, scatter_plot=2, pp = None, titulo = None):
    # Define colors for each class
    yNew = np.zeros(y.shape)
    yNew[y == 1] = int(1)
    yNew[y == 2] = int(2)
    y = np.copy(yNew)
    #print(yNew)
    y_max = np.max(y)
    
    colors = plt.cm.Set1(np.linspace(0, 1, int(y_max)))

    # Set marker size based on class for each observation coordinate
    if y_max == 2:
        sz = [1, 3]  # An empty array specifies the default size of 36 points.
    else:
        sz = np.arange(1, int(y_max) + 1)
    #print(axis_limits)
    # Set axis limits
    if axis_limits is None:
        axis_limits = [np.min(X[:, 0]), np.max(X[:, 0]), np.min(X[:, 1]), np.max(X[:, 1])]
    

    # Set the scatterPlot default option
    if scatter_plot is None:
        scatter_plot = 2

    y = y.astype(int)
    sizes = np.vectorize(lambda val: sz[int(val-1)])(y)
    colors_list = np.take(colors, y-1, mode='clip')
    
    # Create a new figure and an ax object
    fig, ax = plt.subplots()
    ax.set_xlim(axis_limits[0:2])
    ax.set_xbound(axis_limits[0:2])
    ax.set_ylim(axis_limits[2:4])
    ax.set_ybound(axis_limits[2:4])
    

    # Plot the observations with class-specific colors
    if scatter_plot == 1:
        ax.scatter(X[:, 0], X[:, 1], c=colors_list, marker='o', linewidths=1, edgecolors='black')
        ax.set_xlim(axis_limits[0:2])
        ax.set_xbound(axis_limits[0:2])
        ax.set_ylim(axis_limits[2:4])
        ax.set_ybound(axis_limits[2:4])
    elif scatter_plot == 2:
        ax.scatter(X[:, 0], X[:, 1], s=sizes, c=colors_list, linewidths=1)
        ax.set_xlim(axis_limits[0:2])
        ax.set_xbound(axis_limits[0:2])
        ax.set_ylim(axis_limits[2:4])
        ax.set_ybound(axis_limits[2:4])

    #ax.axis('equal')
    ax.set_box_aspect(1)
    ax.grid(False)

    if centroids is not None:
        # Plot the centroids of each cluster
        ax.plot(centroids[:, 0], centroids[:, 1], 'kx', markersize=7, linewidth=10, color = 'red')
        ax.set_xlim(axis_limits[0:2])
        ax.set_xbound(axis_limits[0:2])
        ax.set_ylim(axis_limits[2:4])
        ax.set_ybound(axis_limits[2:4])

        # Plot edges
        if centroids.shape[0] > 2:
            # Calculate the x and y coordinates of Voronoi edges and represent them as column vectors
            vor = Voronoi(centroids)
            #print(ax.axis())
            voronoi_plot_2d(vor, show_vertices=False, line_colors='k', line_width=1, ax=ax, show_points=False)
            ax.set_xlim(axis_limits[0:2])
            ax.set_xbound(axis_limits[0:2])
            ax.set_ylim(axis_limits[2:4])
            ax.set_ybound(axis_limits[2:4])
        elif centroids.shape[0] == 2:
            # Calculate the slope of the line connecting the two centroids
            dy = centroids[1, 1] - centroids[0, 1]
            dx = centroids[1, 0] - centroids[0, 0]
            if dx == 0:
                slope_perpendicular = 0
            else:
                slope = dy / dx
                # Calculate the slope of the line perpendicular to the line connecting the two centroids
                slope_perpendicular = -1 / slope

            # Calculate the midpoint between the two centroids
            mx, my = np.mean(centroids, axis=0)
            
            # Compute two points on the perpendicular line for plotting
            # i want to my delta_x cross the hole plot
            delta_x = (axis_limits[1] - axis_limits[0]) / 2
            x1 = mx - delta_x
            y1 = my - slope_perpendicular * delta_x
            x2 = mx + delta_x
            y2 = my + slope_perpendicular * delta_x
                
            ax.plot([x1, x2], [y1, y2], '-k', linewidth=1)
            ax.set_xlim(axis_limits[0:2])
            ax.set_xbound(axis_limits[0:2])
            ax.set_ylim(axis_limits[2:4])
            ax.set_ybound(axis_limits[2:4])
        
        

    #print("axis_limits", axis_limits)
    if titulo is not None:
        plt.title(titulo)
    plt.show()
    if pp is not None:
        pp.savefig(fig)

    return axis_limits, pp

# %%
def final_plot(X, y, outputRMC, dm_case, axis_limits=None, scatter_plot=2, pp = None):
    # Compute axis limits
    axis_limits = [np.min(X[:, 0]), np.max(X[:, 0]), np.min(X[:, 1]), np.max(X[:, 1])]
    # Create a tiled chart layout
    fig = plt.figure()
    fig.tight_layout()
    fig.subplots_adjust(wspace=0.1, hspace=0.1)
    pp = PdfPages(f'finalplot{dm_case}.pdf')
    _, pp = plot_segmentation(X, y, outputRMC, axis_limits,2,pp, titulo = f'Partição Final DM = { dm_case }')
    pp.close()

# %%
def getRmc(rmH):
    C_list = []
    for i in range(len(rmH)):
        rmC = rmH[i]['rmC']
        if isinstance(rmC, list):
            rmC = rmC[0]
        C_list.append(np.array(rmC))

    outputRMC = np.vstack(C_list)
    return outputRMC

# %% [markdown]
# Plot dm_case 0

# %%
final_plot(data['X'], data['y'], getRmc(fsp0_rmH), 0, axis_limits=None, scatter_plot=2, pp = None)
# Out:
# /var/folders/pt/kgrnh2rn0s39sn57_bb5hggw0000gn/T/ipykernel_2719/188364044.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "kx" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(centroids[:, 0], centroids[:, 1], 'kx', markersize=7, linewidth=10, color = 'red')

# %% [markdown]
# Plot dm_case 1

# %%
final_plot(data['X'], data['y'], getRmc(fsp1_rmH), 1, axis_limits=None, scatter_plot=2, pp = None)
# Out:
# /var/folders/pt/kgrnh2rn0s39sn57_bb5hggw0000gn/T/ipykernel_2719/188364044.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "kx" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(centroids[:, 0], centroids[:, 1], 'kx', markersize=7, linewidth=10, color = 'red')

# %% [markdown]
# Plot dm_case 2

# %%
final_plot(data['X'], data['y'], getRmc(fsp2_rmH), 2, axis_limits=None, scatter_plot=2, pp = None)
# Out:
# /var/folders/pt/kgrnh2rn0s39sn57_bb5hggw0000gn/T/ipykernel_2719/188364044.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "kx" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(centroids[:, 0], centroids[:, 1], 'kx', markersize=7, linewidth=10, color = 'red')

# %% [markdown]
# Plot dm_case 3

# %%
final_plot(data['X'], data['y'], getRmc(fsp3_rmH), 3, axis_limits=None, scatter_plot=2, pp = None)
# Out:
# /var/folders/pt/kgrnh2rn0s39sn57_bb5hggw0000gn/T/ipykernel_2719/188364044.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "kx" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(centroids[:, 0], centroids[:, 1], 'kx', markersize=7, linewidth=10, color = 'red')

# %% [markdown]
# Plot dm_case 4

# %%
final_plot(data['X'], data['y'], getRmc(fsp4_rmH), 4, axis_limits=None, scatter_plot=2, pp = None)
# Out:
# /var/folders/pt/kgrnh2rn0s39sn57_bb5hggw0000gn/T/ipykernel_2719/188364044.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "kx" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(centroids[:, 0], centroids[:, 1], 'kx', markersize=7, linewidth=10, color = 'red')

# %% [markdown]
# ## Plots em conjunto

# %%
def plot_segmentation2(X, y, centroids=None, axis_limits=None, scatter_plot=2, ax=None, titulo = None):
    # Define colors for each class
    yNew = np.zeros(y.shape)
    yNew[y == 1] = int(1)
    yNew[y == 2] = int(2)
    y = np.copy(yNew)
    y_max = np.max(y)
    
    colors = plt.cm.Set1(np.linspace(0, 1, int(y_max)))

    # Set marker size based on class for each observation coordinate
    if y_max == 2:
        sz = [1, 3]
    else:
        sz = np.arange(1, int(y_max) + 1)

    # Set axis limits
    if axis_limits is None:
        axis_limits = [np.min(X[:, 0]), np.max(X[:, 0]), np.min(X[:, 1]), np.max(X[:, 1])]

    # Set the scatterPlot default option
    if scatter_plot is None:
        scatter_plot = 2

    y = y.astype(int)
    sizes = np.vectorize(lambda val: sz[int(val-1)])(y)
    colors_list = np.take(colors, y-1, mode='clip')
    
    # Use the provided ax or create a new one
    if ax is None:
        fig, ax = plt.subplots()
    
    ax.set_xlim(axis_limits[0:2])
    ax.set_xbound(axis_limits[0:2])
    ax.set_ylim(axis_limits[2:4])
    ax.set_ybound(axis_limits[2:4])

    # Plot the observations with class-specific colors
    if scatter_plot == 1:
        ax.scatter(X[:, 0], X[:, 1], c=colors_list, marker='o', linewidths=1, edgecolors='black')
    elif scatter_plot == 2:
        ax.scatter(X[:, 0], X[:, 1], s=sizes, c=colors_list, linewidths=1)

    ax.set_box_aspect(1)
    ax.grid(False)

    if centroids is not None:
        # Plot the centroids of each cluster
        ax.plot(centroids[:, 0], centroids[:, 1], 'kx', markersize=7, linewidth=10, color = 'red')

        # Plot edges
        if centroids.shape[0] > 2:
            vor = Voronoi(centroids)
            voronoi_plot_2d(vor, show_vertices=False, line_colors='k', line_width=1, ax=ax, show_points=False)
        elif centroids.shape[0] == 2:
            dy = centroids[1, 1] - centroids[0, 1]
            dx = centroids[1, 0] - centroids[0, 0]
            if dx == 0:
                slope_perpendicular = 0
            else:
                slope = dy / dx
                slope_perpendicular = -1 / slope

            mx, my = np.mean(centroids, axis=0)
            
            delta_x = (axis_limits[1] - axis_limits[0]) / 2
            x1 = mx - delta_x
            y1 = my - slope_perpendicular * delta_x
            x2 = mx + delta_x
            y2 = my + slope_perpendicular * delta_x
                
            ax.plot([x1, x2], [y1, y2], '-k', linewidth=1)
        
    if titulo is not None:
        ax.set_title(titulo)

# %%
def final_plot2(X, y, rmcs, dm_cases, axis_limits=None, scatter_plot=2):
    # Compute axis limits
    if axis_limits is None:
        axis_limits = [np.min(X[:, 0]), np.max(X[:, 0]), np.min(X[:, 1]), np.max(X[:, 1])]
    
    # Calculate the number of rows and columns for the subplots
    n = len(dm_cases)
    nrows = int(np.sqrt(n))
    ncols = int(np.ceil(n / nrows))
    
    # Create a tiled chart layout
    fig, axs = plt.subplots(nrows, ncols, figsize=(15, 15))
    fig.tight_layout()
    fig.subplots_adjust(wspace=0.1, hspace=0.1)
    
    # Flatten the array of axes
    axs = axs.flatten()
    
    # Iterate over each dm_case and plot it in a subplot
    for i, (dm_case, rmc) in enumerate(zip(dm_cases, rmcs)):
        ax = axs[i]
        plot_segmentation(X, y, rmc, axis_limits, scatter_plot, ax, titulo=f'Partição Final DM = {dm_case}')
    
    # Remove any unused subplots
    for j in range(i+1, len(axs)):
        fig.delaxes(axs[j])
    
    plt.show()

# %%
# Plotando todos juntos
final_plot2(data['X'], data['y'], [getRmc(fsp0_rmH), getRmc(fsp1_rmH), getRmc(fsp2_rmH), getRmc(fsp3_rmH), getRmc(fsp4_rmH)], [0, 1, 2, 3, 4], axis_limits=None, scatter_plot=2)
# Out:
# /var/folders/pt/kgrnh2rn0s39sn57_bb5hggw0000gn/T/ipykernel_2719/188364044.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "kx" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(centroids[:, 0], centroids[:, 1], 'kx', markersize=7, linewidth=10, color = 'red')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 2
#       1 # Plotando todos juntos
# ----> 2 final_plot2(data['X'], data['y'], [getRmc(fsp0_rmH), getRmc(fsp1_rmH), getRmc(fsp2_rmH), getRmc(fsp3_rmH), getRmc(fsp4_rmH)], [0, 1, 2, 3, 4], axis_limits=None, scatter_plot=2)
#
# Cell In[71], line 22, in final_plot2(X, y, rmcs, dm_cases, axis_limits, scatter_plot)
#      20 for i, (dm_case, rmc) in enumerate(zip(dm_cases, rmcs)):
#      21     ax = axs[i]
# ---> 22     plot_segmentation(X, y, rmc, axis_limits, scatter_plot, ax, titulo=f'Partição Final DM = {dm_case}')
#      24 # Remove any unused subplots
#      25 for j in range(i+1, len(axs)):
#
# Cell In[62], line 110, in plot_segmentation(X, y, centroids, axis_limits, scatter_plot, pp, titulo)
#     108 plt.show()
#     109 if pp is not None:
# --> 110     pp.savefig(fig)
#     112 return axis_limits, pp
#
# AttributeError: 'Axes' object has no attribute 'savefig'
